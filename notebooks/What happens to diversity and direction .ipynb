# %%
import matplotlib.pyplot as plt
import pandas as pd
% matplotlib inline

# %%
df = pd.read_csv('diversity_and_direction.txt')

#df = df.drop(columns=['Unnamed: 3'])
df['diversity'] = pd.to_numeric(df['diversity'])
df['direction']= pd.to_numeric(df['direction'])
#df['best_position']= pd.to_numeric(df['direction'])
df.head()
# Out:
#    diversity  direction  best_fitness
# 0   0.296501          1     10.966160
# 1   0.280621          1      6.080625
# 2   0.263054          1      0.996803
# 3   0.218385          1      0.975703
# 4   0.199007         -1      0.844421

# %%
df['diversity'].plot()

# %%
df['direction'].plot()

# %%
df['best_fitness'].plot(ylim=(None))
